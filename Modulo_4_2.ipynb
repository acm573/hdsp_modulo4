# %% [markdown]
# ### Busca un conjunto de datos de tu interés, que se encuentre en una página web y documenta:
#
# - Qué tendrías que hacer para que la información esté en la calidad que la necesitas
# - Existe información faltante en la data que observas para contar una historia más completa
# - Código de la extracción de la información
#
# La información utilizada para el ejercicio es la de la URL https://search.bvsalud.org/global-literature-on-novel-coronavirus-2019-ncov/?output=site&lang=en&from=1&sort=&format=summary&count=20&fb=&page=1&skfp=&index=&q=

# %% [markdown]
# ### Librerías

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Configuración

# %% [markdown]
# - Para la búsqueda, se estará variando el parámetro "from" incrementando cada vez con el número de elementos que se haya localizado en la página anterior.
#
# - Count se puede ajustar con valores de 20, 50 y 100
#
# - Page se incrementará de 1 en 1

# %%
#URL base 
base_url = 'https://search.bvsalud.org/global-literature-on-novel-coronavirus-2019-ncov/'

#Parámetros a modificar
params = {
    'output': 'site',
    'lang': 'en',
    'from': 1,
    'sort': '',
    'format': 'summary',
    'count': 100,
    'fb': '',
    'page': 1,
    'skfp': '',
    'index': '',
    'q': ''
}

# %% [markdown]
# ### Extracción de información

# %%
#Lista para almacenar los datos antes de crear el DataFrame
data = []

detener = 10   #Para prueba se coloca una página de paro
                #con -1 hasta agotar el contenido del sitio
    
#Inicia el ciclo 
while True:
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        boxes = soup.find_all('div', class_='box1')
        
        #Si no se encuentran más 'box1', romper el bucle
        if not boxes:
            break
        
        for box in boxes:
            title = box.find('div', class_='titleArt').get_text(strip=True) if box.find('div', class_='titleArt') else ''
            authors = box.find('div', class_='author').get_text(strip=True) if box.find('div', class_='author') else ''
            reference = box.find('div', class_='reference').get_text(strip=True) if box.find('div', class_='reference') else ''
            data_article = box.find('div', class_='dataArticle').get_text(strip=True) if box.find('div', class_='dataArticle') else ''
            
            #Añade la información a la lista
            data.append({'Title': title, 'Authors': authors, 'Reference': reference, 'Data Article': data_article})
            
        print('Analizando página: ', params['page'])
        
        #Incrementa página
        params['page'] += 1
        params['from'] += len(boxes)
    else:
        print(f'La solicitud a la URL falló con código de estado {response.status_code}.')
        break
        
    if detener != -1:
        if detener == (params['page']-1):
            break;

df = pd.DataFrame(data)
df.shape
# Out:
# Analizando página:  1
# Analizando página:  2
# Analizando página:  3
# Analizando página:  4
# Analizando página:  5
# Analizando página:  6
# Analizando página:  7
# Analizando página:  8
# Analizando página:  9
# Analizando página:  10
# (1000, 4)

# %%
df.head(20)
# Out:
#                                                 Title  \
# 0   Data-Set Class-Balancing and the Convolutional...
# 1   Refueling a Quiet Fire: Old Truthers and New D...
# 2   From Consumer Cities to Consumer Towns? The Po...
# 3   The Effect of School Closures on Standardized ...
# 4   Timely Reporting During The SARS-CoV-2 Lockdow...
# 5   Comparing Use of B-cell depletion therapy to I...
# 6   Tip of the Iceberg: A New Wave of Iron-Sulfur ...
# 7   Cumulative Stressors Influence Lag on Children...
# 8   Construction and Immunogenicity of SARS-CoV-2 ...
# 9   A Comprehensive Review of COVID-19 Infection a...
# 10  COVID-19 Impacts on Mexican Power Sector (prep...
# 11  Historical Perspectives in the Pedagogy of Ana...
# 12  Analyzing Public Reactions, Perceptions, and A...
# 13  A Large-Scale Dataset of Search Interests Rela...
# 14  The impact of the COVID-19 ‘anthropause’ on Ma...
# 15  Clinical, laboratory, and imaging findings of ...
# 16  UVAE: Integration of Heterogeneous Unpaired Da...
# 17  Navigating Uncertainty: Teachers’ Insights on ...
# 18  Moral Resilience Reduces Levels of Quiet Quitt...
# 19  Is high COVID-19 vaccination reducing natural ...
#
#                                               Authors  \
# 0   Andres Escobar;Maria Alejandra Amezquita Dussa...
# 1   Gabriele Beccari;Matilde Giaccherini;Joanna Ko...
# 2                                        Binzhe Wang.
# 3                  Christian Gillitzer;Nalini Prasad.
# 4   Md. Safiullah;Anisuddin Ahmed;Mohammed Moshtaq...
# 5               Western Sydney Local Health District.
# 6                     Audrey L Heffner;Nunziata Maio.
# 7   Ana Moscoso;Anthony Cousien;Giulia Serra;Annet...
# 8   Hai Trong Nguyen;Darryl Falzarano;Volker Gerdt...
# 9   Evangelos Sakellariou;Evangelia Argyropoulou;P...
# 10  Lizbeth Salgado-Conrado;Carlos Álvarez-Macías;...
# 11  Orien Tulp;Frantz Sainvil;Rolando Branly;Haili...
# 12     Nirmalya Thakur;Yuvraj Nihal Duggal;Zihui Liu.
# 13  Nirmalya Thakur;Shuqi Cui;Kesha A. Patel;Isabe...
# 14  Jens J. Currie;Florence A. Sullivan;Elizabeth ...
# 15  Ahsan Ullah;Asia Khanam;Mina Mondal;Md Rezwanu...
# 16  Mike Phuycharoen;Verena Kaestele;Thomas Willia...
# 17                          Yonit Nissim;Eitan Simon.
# 18  Petros Galanis;Ioannis Moisoglou;Aglaia Katsir...
# 19                                       Indrani Roy.
#
#                                            Reference  \
# 0                                        ssrn; 2023.
# 1                                        ssrn; 2023.
# 2                                        ssrn; 2023.
# 3                                        ssrn; 2023.
# 4                                        ssrn; 2023.
# 5   ANZCTR; 19/12/2023; TrialID: ACTRN12623001336673
# 6                               preprints.org; 2023.
# 7                                        ssrn; 2023.
# 8                               preprints.org; 2023.
# 9                               preprints.org; 2023.
# 10                              preprints.org; 2023.
# 11                              preprints.org; 2023.
# 12                                      arxiv; 2023.
# 13                                      arxiv; 2023.
# 14                             researchsquare; 2023.
# 15                                    medrxiv; 2023.
# 16                                    biorxiv; 2023.
# 17                              preprints.org; 2023.
# 18                              preprints.org; 2023.
# 19                         authorea preprints; 2023.
#
#                                          Data Article
# 0   Preprint\n            in English| PREPRINT-SSR...
# 1   Preprint\n            in English| PREPRINT-SSR...
# 2   Preprint\n            in English| PREPRINT-SSR...
# 3   Preprint\n            in English| PREPRINT-SSR...
# 4   Preprint\n            in English| PREPRINT-SSR...
# 5   Clinical Trial Register| ICTRP    \t| ID:ictrp...
# 6   Preprint\n            in English| PREPRINT-PRE...
# 7   Preprint\n            in English| PREPRINT-SSR...
# 8   Preprint\n            in English| PREPRINT-PRE...
# 9   Preprint\n            in English| PREPRINT-PRE...
# 10  Preprint\n            in English| PREPRINT-PRE...
# 11  Preprint\n            in English| PREPRINT-PRE...
# 12  Preprint\n            in English| PREPRINT-ARX...
# 13  Preprint\n            in English| PREPRINT-ARX...
# 14  Preprint\n            in English| PREPRINT-RES...
# 15  Preprint\n            in English| medRxiv    \...
# 16  Preprint\n            in English| bioRxiv    \...
# 17  Preprint\n            in English| PREPRINT-PRE...
# 18  Preprint\n            in English| PREPRINT-PRE...
# 19  Preprint\n            in English| PREPRINT-AUT...
